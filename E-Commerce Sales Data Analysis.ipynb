# %%
# 1. Provide a visual representation of our annual sales performance over time?

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Month': pd.date_range(start='2024-01-01', periods=36, freq='M'),
    'Sales': [120, 135, 150, 145, 160, 155, 180, 175, 190, 185, 200, 195,
              210, 205, 220, 215, 230, 225, 240, 235, 250, 245, 260, 255,
              270, 275, 280, 285, 290, 295, 300, 305, 310, 315, 320, 325]
}

df = pd.DataFrame(data)

df.head()
# Out:
# C:\Users\Anoop Raj\AppData\Local\Temp\ipykernel_1000\1949450482.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   'Month': pd.date_range(start='2024-01-01', periods=36, freq='M'),
#        Month  Sales
# 0 2024-01-31    120
# 1 2024-02-29    135
# 2 2024-03-31    150
# 3 2024-04-30    145
# 4 2024-05-31    160

# %%
df['Year'] = df['Month'].dt.year
annual_sales = df.groupby('Year')['Sales'].sum().reset_index()

annual_sales
# Out:
#    Year  Sales
# 0  2024   1990
# 1  2025   2790
# 2  2026   3570

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Month': pd.date_range(start='2021-01-01', periods=36, freq='M'),
    'Sales': [120, 135, 150, 145, 160, 155, 180, 175, 190, 185, 200, 195,
              210, 205, 220, 215, 230, 225, 240, 235, 250, 245, 260, 255,
              270, 275, 280, 285, 290, 295, 300, 305, 310, 315, 320, 325]
}

df = pd.DataFrame(data)

df['Year'] = df['Month'].dt.year
annual_sales = df.groupby('Year')['Sales'].sum().reset_index()

plt.figure(figsize=(10, 5))
plt.plot(annual_sales['Year'], annual_sales['Sales'], marker='o')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.title('Annual Sales Performance Over Time')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Anoop Raj\AppData\Local\Temp\ipykernel_1000\1923716621.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   'Month': pd.date_range(start='2021-01-01', periods=36, freq='M'),

# %%
# 2. The client is interested in understanding how the sales have been fluctuating 
#     over time to identify any underlying patterns or anomalies Analyze the trend in
#     our monthly sales using a moving average technique.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = {
    'Month': pd.date_range(start='2024-01-01', periods=24, freq='M'),
    'Sales': [120, 135, 150, 145, 160, 155, 180, 175, 190, 185, 200, 195,
              210, 205, 220, 215, 230, 225, 240, 235, 250, 245, 260, 255]
}

df = pd.DataFrame(data)

df.head()
# Out:
# C:\Users\Anoop Raj\AppData\Local\Temp\ipykernel_1000\937147888.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   'Month': pd.date_range(start='2024-01-01', periods=24, freq='M'),
#        Month  Sales
# 0 2024-01-31    120
# 1 2024-02-29    135
# 2 2024-03-31    150
# 3 2024-04-30    145
# 4 2024-05-31    160

# %%
df['3_Month_MA'] = df['Sales'].rolling(window=3).mean()

df.head()
# Out:
#        Month  Sales  3_Month_MA
# 0 2024-01-31    120         NaN
# 1 2024-02-29    135         NaN
# 2 2024-03-31    150  135.000000
# 3 2024-04-30    145  143.333333
# 4 2024-05-31    160  151.666667

# %%
plt.figure(figsize=(20,10))
plt.plot(df['Month'], df['Sales'], label='Monthly Sales')
plt.plot(df['Month'], df['3_Month_MA'], label='3-Month Moving Average', color='orange')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales and 3-Month Moving Average')
plt.xticks(rotation=20)
plt.legend()
plt.grid(True)
plt.show()

# %%
# 3. Explore the month-over-month growth rate in sales.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = {
    'Month': pd.date_range(start='2024-01-01', periods=24, freq='M'),
    'Sales': [120, 135, 150, 145, 160, 155, 180, 175, 190, 185, 200, 195,
              210, 205, 220, 215, 230, 225, 240, 235, 250, 245, 260, 255]
}

df = pd.DataFrame(data)

df.head()
# Out:
# C:\Users\Anoop Raj\AppData\Local\Temp\ipykernel_1000\937147888.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   'Month': pd.date_range(start='2024-01-01', periods=24, freq='M'),
#        Month  Sales
# 0 2024-01-31    120
# 1 2024-02-29    135
# 2 2024-03-31    150
# 3 2024-04-30    145
# 4 2024-05-31    160

# %%
df['3_Month_MA'] = df['Sales'].rolling(window=3).mean()

df.head()
# Out:
#        Month  Sales  3_Month_MA
# 0 2024-01-31    120         NaN
# 1 2024-02-29    135         NaN
# 2 2024-03-31    150  135.000000
# 3 2024-04-30    145  143.333333
# 4 2024-05-31    160  151.666667

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Month'], df['Sales'], label='Monthly Sales')
plt.plot(df['Month'], df['3_Month_MA'], label='3-Month Moving Average', color='orange')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales and 3-Month Moving Average')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 4. identify the top-performing sales representatives based on their total sales
#    volume.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Month': pd.date_range(start='2024-01-01', periods=36, freq='M'),
    'Sales': [120, 135, 150, 145, 160, 155, 180, 175, 190, 185, 200, 195,
              210, 205, 220, 215, 230, 225, 240, 235, 250, 245, 260, 255,
              270, 275, 280, 285, 290, 295, 300, 305, 310, 315, 320, 325]
}

df = pd.DataFrame(data)

df.head()
# Out:
# C:\Users\Anoop Raj\AppData\Local\Temp\ipykernel_1000\1949450482.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   'Month': pd.date_range(start='2024-01-01', periods=36, freq='M'),
#        Month  Sales
# 0 2024-01-31    120
# 1 2024-02-29    135
# 2 2024-03-31    150
# 3 2024-04-30    145
# 4 2024-05-31    160

# %%
df['MoM_Growth_Rate'] = df['Sales'].pct_change() * 100

df.head()
# Out:
#        Month  Sales  MoM_Growth_Rate
# 0 2024-01-31    120              NaN
# 1 2024-02-29    135        12.500000
# 2 2024-03-31    150        11.111111
# 3 2024-04-30    145        -3.333333
# 4 2024-05-31    160        10.344828

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Month': pd.date_range(start='2021-01-01', periods=36, freq='M'),
    'Sales': [120, 135, 150, 145, 160, 155, 180, 175, 190, 185, 200, 195,
              210, 205, 220, 215, 230, 225, 240, 235, 250, 245, 260, 255,
              270, 275, 280, 285, 290, 295, 300, 305, 310, 315, 320, 325]
}

df = pd.DataFrame(data)

df['MoM_Growth_Rate'] = df['Sales'].pct_change() * 100

plt.figure(figsize=(12, 6))
plt.plot(df['Month'], df['MoM_Growth_Rate'], marker='o', linestyle='-')
plt.xlabel('Month')
plt.ylabel('MoM Growth Rate (%)')
plt.title('Month-Over-Month Growth Rate in Sales')
plt.grid(True)
plt.axhline(0, color='red', linestyle='--')
plt.show()
# Out:
# C:\Users\Anoop Raj\AppData\Local\Temp\ipykernel_1000\180584148.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   'Month': pd.date_range(start='2021-01-01', periods=36, freq='M'),

# %%
df
# Out:
#         Month  Sales  MoM_Growth_Rate
# 0  2021-01-31    120              NaN
# 1  2021-02-28    135        12.500000
# 2  2021-03-31    150        11.111111
# 3  2021-04-30    145        -3.333333
# 4  2021-05-31    160        10.344828
# 5  2021-06-30    155        -3.125000
# 6  2021-07-31    180        16.129032
# 7  2021-08-31    175        -2.777778
# 8  2021-09-30    190         8.571429
# 9  2021-10-31    185        -2.631579
# 10 2021-11-30    200         8.108108
# 11 2021-12-31    195        -2.500000
# 12 2022-01-31    210         7.692308
# 13 2022-02-28    205        -2.380952
# 14 2022-03-31    220         7.317073
# 15 2022-04-30    215        -2.272727
# 16 2022-05-31    230         6.976744
# 17 2022-06-30    225        -2.173913
# 18 2022-07-31    240         6.666667
# 19 2022-08-31    235        -2.083333
# 20 2022-09-30    250         6.382979
# 21 2022-10-31    245        -2.000000
# 22 2022-11-30    260         6.122449
# 23 2022-12-31    255        -1.923077
# ...

# %%
# 5. What are the total sales made by each employee?

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Representative': ['Anoop', 'Sumit', 'Anupam', 'Anoop', 'Sumit', 'Anupam', 'Anoop', 'Sumit', 'Anupam'],
    'Sales': [500, 700, 400, 600, 800, 450, 700, 850, 500]
}

df = pd.DataFrame(data)

total_sales_by_rep = df.groupby('Representative')['Sales'].sum().reset_index()

top_performers = total_sales_by_rep.sort_values(by='Sales', ascending=False)

# Display the top performers
print(top_performers)

plt.figure(figsize=(14, 7))
plt.bar(top_performers['Representative'], top_performers['Sales'], color='pink')
plt.xlabel('Representative')
plt.ylabel('Total Sales')
plt.title('Top-Performing Sales Representatives')
plt.xticks(rotation=20)
plt.grid(axis='y')
plt.show()
# Out:
#   Representative  Sales
# 2          Sumit   2350
# 0          Anoop   1800
# 1         Anupam   1350

# %%
df
# Out:
#   Representative  Sales
# 0          Anoop    500
# 1          Sumit    700
# 2         Anupam    400
# 3          Anoop    600
# 4          Sumit    800
# 5         Anupam    450
# 6          Anoop    700
# 7          Sumit    850
# 8         Anupam    500

# %%
import pandas as pd

data = {
    'Employee': ['Anoop', 'Sumit', 'Anupam', 'Anoop', 'Sumit', 'Anupam', 'Anoop', 'Sumit', 'Anupam'],
    'Sales': [500, 700, 400, 600, 800, 450, 700, 850, 500]
}

df = pd.DataFrame(data)

df
# Out:
#   Employee  Sales
# 0    Anoop    500
# 1    Sumit    700
# 2   Anupam    400
# 3    Anoop    600
# 4    Sumit    800
# 5   Anupam    450
# 6    Anoop    700
# 7    Sumit    850
# 8   Anupam    500

# %%
import pandas as pd

data = {
    'Employee': ['Anoop', 'Sumit', 'Anupam', 'Anoop', 'Sumit', 'Anupam', 'Anoop', 'Sumit', 'Anupam'],
    'Sales': [500, 700, 400, 600, 800, 450, 700, 850, 500]
}

df = pd.DataFrame(data)

total_sales_by_employee = df.groupby('Employee')['Sales'].sum().reset_index()

print(total_sales_by_employee)
# Out:
#   Employee  Sales
# 0    Anoop   1800
# 1   Anupam   1350
# 2    Sumit   2350

# %%
df
# Out:
#   Employee  Sales
# 0    Anoop    500
# 1    Sumit    700
# 2   Anupam    400
# 3    Anoop    600
# 4    Sumit    800
# 5   Anupam    450
# 6    Anoop    700
# 7    Sumit    850
# 8   Anupam    500

# %%
# 6. Which category has the highest total sales?

# %%
import pandas as pd

data = {
    'Category': ['Electronics', 'Furniture', 'Office Supplies', 'Electronics', 'Furniture', 'Office Supplies', 'Electronics', 'Furniture', 'Office Supplies'],
    'Sales': [1500, 2000, 300, 2500, 1800, 400, 3200, 1600, 350]
}

df = pd.DataFrame(data)

df
# Out:
#           Category  Sales
# 0      Electronics   1500
# 1        Furniture   2000
# 2  Office Supplies    300
# 3      Electronics   2500
# 4        Furniture   1800
# 5  Office Supplies    400
# 6      Electronics   3200
# 7        Furniture   1600
# 8  Office Supplies    350

# %%
total_sales_by_category = df.groupby('Category')['Sales'].sum().reset_index()

total_sales_by_category = total_sales_by_category.sort_values(by='Sales', ascending=False)

total_sales_by_category
# Out:
#           Category  Sales
# 0      Electronics   7200
# 1        Furniture   5400
# 2  Office Supplies   1050

# %%
top_category = total_sales_by_category.iloc[0]

top_category
# Out:
# Category    Electronics
# Sales              7200
# Name: 0, dtype: object

# %%
df
# Out:
#           Category  Sales
# 0      Electronics   1500
# 1        Furniture   2000
# 2  Office Supplies    300
# 3      Electronics   2500
# 4        Furniture   1800
# 5  Office Supplies    400
# 6      Electronics   3200
# 7        Furniture   1600
# 8  Office Supplies    350

# %%
import pandas as pd

data = {
    'Category': ['Electronics', 'Furniture', 'Office Supplies', 'Electronics', 'Furniture', 'Office Supplies', 'Electronics', 'Furniture', 'Office Supplies'],
    'Sales': [1500, 2000, 300, 2500, 1800, 400, 3200, 1600, 350]
}

df = pd.DataFrame(data)

total_sales_by_category = df.groupby('Category')['Sales'].sum().reset_index()

total_sales_by_category = total_sales_by_category.sort_values(by='Sales', ascending=False)

print(total_sales_by_category)

top_category = total_sales_by_category.iloc[0]

print(f"The category with the highest total sales is {top_category['Category']} with sales of {top_category['Sales']}.")
# Out:
#           Category  Sales
# 0      Electronics   7200
# 1        Furniture   5400
# 2  Office Supplies   1050
# The category with the highest total sales is Electronics with sales of 7200.

# %%
df
# Out:
#           Category  Sales
# 0      Electronics   1500
# 1        Furniture   2000
# 2  Office Supplies    300
# 3      Electronics   2500
# 4        Furniture   1800
# 5  Office Supplies    400
# 6      Electronics   3200
# 7        Furniture   1600
# 8  Office Supplies    350

# %%
# 7. How many customers are there in each state?

# %%
import pandas as pd

data = {
    'Customer': ['Anoop Raj', 'Sumit Kumar', 'Anupam Raj', 'Nitin Kumar', 'Krishna Venom', 'Neelesh Varma', 'Shivam Raj', 'Shyam Singh', 'Milan Raj'],
    'State': ['Uttar Pradesh', 'Uttar Pradesh', 'Delhi', 'Uttar Pradesh', 'Delhi', 'Bihar', 'Bihar', 'Uttar Pradesh', 'Delhi']
}

df = pd.DataFrame(data)

df
# Out:
#         Customer          State
# 0      Anoop Raj  Uttar Pradesh
# 1    Sumit Kumar  Uttar Pradesh
# 2     Anupam Raj          Delhi
# 3    Nitin Kumar  Uttar Pradesh
# 4  Krishna Venom          Delhi
# 5  Neelesh Varma          Bihar
# 6     Shivam Raj          Bihar
# 7    Shyam Singh  Uttar Pradesh
# 8      Milan Raj          Delhi

# %%
customers_by_state = df.groupby('State')['Customer'].count().reset_index()

customers_by_state.columns = ['State', 'Number of Customers']

customers_by_state
# Out:
#            State  Number of Customers
# 0          Bihar                    2
# 1          Delhi                    3
# 2  Uttar Pradesh                    4

# %%
import pandas as pd

data = {
    'Customer': ['Anoop Raj', 'Sumit Kumar', 'Anupam Raj', 'Nitin Kumar', 'Krishna Venom', 'Neelesh Varma', 'Shivam Raj', 'Shyam Singh', 'Milan Raj'],
    'State': ['Uttar Pradesh', 'Uttar Pradesh', 'Delhi', 'Uttar Pradesh', 'Delhi', 'Bihar', 'Bihar', 'Uttar Pradesh', 'Delhi']
}

df = pd.DataFrame(data)

customers_by_state = df.groupby('State')['Customer'].count().reset_index()

customers_by_state.columns = ['State', 'Number of Customers']

print(customers_by_state)
# Out:
#            State  Number of Customers
# 0          Bihar                    2
# 1          Delhi                    3
# 2  Uttar Pradesh                    4

# %%
df
# Out:
#         Customer          State
# 0      Anoop Raj  Uttar Pradesh
# 1    Sumit Kumar  Uttar Pradesh
# 2     Anupam Raj          Delhi
# 3    Nitin Kumar  Uttar Pradesh
# 4  Krishna Venom          Delhi
# 5  Neelesh Varma          Bihar
# 6     Shivam Raj          Bihar
# 7    Shyam Singh  Uttar Pradesh
# 8      Milan Raj          Delhi

# %%
# 8. What is the average quantity of each product sold?

# %%
import pandas as pd

data = {
    'Product': ['Product A', 'Product B', 'Product C', 'Product A', 'Product B', 'Product C', 'Product A', 'Product B', 'Product C'],
    'Quantity': [10, 20, 15, 12, 18, 17, 14, 22, 19]
}

df = pd.DataFrame(data)

df
# Out:
#      Product  Quantity
# 0  Product A        10
# 1  Product B        20
# 2  Product C        15
# 3  Product A        12
# 4  Product B        18
# 5  Product C        17
# 6  Product A        14
# 7  Product B        22
# 8  Product C        19

# %%
average_quantity_by_product = df.groupby('Product')['Quantity'].mean().reset_index()

average_quantity_by_product.columns = ['Product', 'Average Quantity Sold']

average_quantity_by_product
# Out:
#      Product  Average Quantity Sold
# 0  Product A                   12.0
# 1  Product B                   20.0
# 2  Product C                   17.0

# %%
import pandas as pd

data = {
    'State': ['UP', 'UK', 'UP', 'MP', 'UK', 'MP'],
    'Sales Amount': [1500, 2000, 1800, 1300, 2200, 1700]
}

df = pd.DataFrame(data)

total_sales_by_state = df.groupby('State')['Sales Amount'].sum()

print(total_sales_by_state)
# Out:
# State
# MP    3000
# UK    4200
# UP    3300
# Name: Sales Amount, dtype: int64

# %%
df
# Out:
#   State  Sales Amount
# 0    UP          1500
# 1    UK          2000
# 2    UP          1800
# 3    MP          1300
# 4    UK          2200
# 5    MP          1700

# %%
# 11. How many sales were made by each customer?

# %%
import pandas as pd

data = {
    'Customer Name': ['Anju Raj', 'Sumit Kumar', 'Anju Raj', 'Anupam Raj', 'Sumit Kumar','Anupam Raj'],
    'Sales Amount': [150, 200, 180, 130, 220, 170]
}

df = pd.DataFrame(data)

sales_count_by_customer = df.groupby('Customer Name').size()

print(sales_count_by_customer)
# Out:
# Customer Name
# Anju Raj       2
# Anupam Raj     2
# Sumit Kumar    2
# dtype: int64

# %%
df
# Out:
#   Customer Name  Sales Amount
# 0      Anju Raj           150
# 1   Sumit Kumar           200
# 2      Anju Raj           180
# 3    Anupam Raj           130
# 4   Sumit Kumar           220
# 5    Anupam Raj           170

# %%
# 12. What is the total salary expenditure on employees in each department?

# %%
import pandas as pd

data = {
    'Employee Name': ['Anju Raj', 'Sumit Kumar', 'Anoop Raj', 'Anupam Raj', 'Shivam Kumar','Neelesh Raj'],
    'Department': ['Sales', 'HR', 'Sales', 'HR', 'IT', 'IT'],
    'Salary': [50000, 60000, 55000, 58000, 70000, 72000]
}

df = pd.DataFrame(data)

total_salary_by_department = df.groupby('Department')['Salary'].sum()

print(total_salary_by_department)
# Out:
# Department
# HR       118000
# IT       142000
# Sales    105000
# Name: Salary, dtype: int64

# %%
df
# Out:
#   Employee Name Department  Salary
# 0      Anju Raj      Sales   50000
# 1   Sumit Kumar         HR   60000
# 2     Anoop Raj      Sales   55000
# 3    Anupam Raj         HR   58000
# 4  Shivam Kumar         IT   70000
# 5   Neelesh Raj         IT   72000

# %%
# 13. Which subcategory has the highest average unit price?

# %%
import pandas as pd

data = {
    'Subcategory': ['Electronics', 'Clothing', 'Electronics', 'Furniture', 'Clothing', 'Furniture'],
    'Unit Price': [100, 80, 120, 150, 90, 180]
}

df = pd.DataFrame(data)

average_unit_price_by_subcategory = df.groupby('Subcategory')['Unit Price'].mean()

highest_avg_unit_price_subcategory = average_unit_price_by_subcategory.idxmax()
highest_avg_unit_price = average_unit_price_by_subcategory.max()

print(f"The subcategory with the highest average unit price is {highest_avg_unit_price_subcategory} with an average unit price of {highest_avg_unit_price}.")
# Out:
# The subcategory with the highest average unit price is Furniture with an average unit price of 165.0.

# %%
df
# Out:
#    Subcategory  Unit Price
# 0  Electronics         100
# 1     Clothing          80
# 2  Electronics         120
# 3    Furniture         150
# 4     Clothing          90
# 5    Furniture         180

# %%
# 14. What is the total revenue generated from sales in each category?

# %%
import pandas as pd

data = {
    'Category': ['Electronics', 'Clothing', 'Electronics', 'Furniture', 'Clothing', 'Furniture'],
    'Sales Amount': [5000, 7000, 6000, 8000, 9000, 10000]
}

df = pd.DataFrame(data)

total_revenue_by_category = df.groupby('Category')['Sales Amount'].sum()

print(total_revenue_by_category)
# Out:
# Category
# Clothing       16000
# Electronics    11000
# Furniture      18000
# Name: Sales Amount, dtype: int64

# %%
df
# Out:
#       Category  Sales Amount
# 0  Electronics          5000
# 1     Clothing          7000
# 2  Electronics          6000
# 3    Furniture          8000
# 4     Clothing          9000
# 5    Furniture         10000
